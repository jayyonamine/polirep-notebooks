# %% [markdown]
# # Without Roots: The Political Consequences of Collective Economic Shocks
#
# **Authors:** Cremaschi, Simone, Bariletto, Nicola, De Vries, Catherine E.
#
# **Journal:** American Political Science Review (2025)
#
# This notebook reproduces the analysis from the paper above.
# It was auto-generated by [PoliRep](https://polirep.org).
#
# ---

# %% [markdown]
# ## Setup & Data Loading
#
# Load datasets from BigQuery using bigrquery. The dataset is public,
# but you need a GCP project for billing.
#
# Set `project_id` to your own GCP project ID below.

# %%
# Install required packages (uncomment if needed)
# install.packages(c("bigrquery", "DBI"))

library(bigrquery)
library(DBI)

# Set your GCP project ID for billing
project_id <- "polirep-app"  # Change this to your GCP project

# %%
# Load Decessi_ComuneResidenza_Sesso_Causa-Anno2005.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_decessi_comuneresidenza_sesso_causa_anno2005`"
decessi_comuneresidenza_sesso_causa_anno2005 <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("decessi_comuneresidenza_sesso_causa_anno2005: %d rows, %d columns\n", nrow(decessi_comuneresidenza_sesso_causa_anno2005), ncol(decessi_comuneresidenza_sesso_causa_anno2005)))
head(decessi_comuneresidenza_sesso_causa_anno2005)

# %%
# Load Decessi_ComuneResidenza_Sesso_Causa-Anno2006.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_decessi_comuneresidenza_sesso_causa_anno2006`"
decessi_comuneresidenza_sesso_causa_anno2006 <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("decessi_comuneresidenza_sesso_causa_anno2006: %d rows, %d columns\n", nrow(decessi_comuneresidenza_sesso_causa_anno2006), ncol(decessi_comuneresidenza_sesso_causa_anno2006)))
head(decessi_comuneresidenza_sesso_causa_anno2006)

# %%
# Load Decessi_ComuneResidenza_Sesso_Causa-Anno2007.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_decessi_comuneresidenza_sesso_causa_anno2007`"
decessi_comuneresidenza_sesso_causa_anno2007 <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("decessi_comuneresidenza_sesso_causa_anno2007: %d rows, %d columns\n", nrow(decessi_comuneresidenza_sesso_causa_anno2007), ncol(decessi_comuneresidenza_sesso_causa_anno2007)))
head(decessi_comuneresidenza_sesso_causa_anno2007)

# %%
# Load Decessi_ComuneResidenza_Sesso_Causa-Anno2008.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_decessi_comuneresidenza_sesso_causa_anno2008`"
decessi_comuneresidenza_sesso_causa_anno2008 <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("decessi_comuneresidenza_sesso_causa_anno2008: %d rows, %d columns\n", nrow(decessi_comuneresidenza_sesso_causa_anno2008), ncol(decessi_comuneresidenza_sesso_causa_anno2008)))
head(decessi_comuneresidenza_sesso_causa_anno2008)

# %%
# Load admin_boundaries_23.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_admin_boundaries_23`"
admin_boundaries_23 <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("admin_boundaries_23: %d rows, %d columns\n", nrow(admin_boundaries_23), ncol(admin_boundaries_23)))
head(admin_boundaries_23)

# %%
# Load agri_surface.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_agri_surface`"
agri_surface <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("agri_surface: %d rows, %d columns\n", nrow(agri_surface), ncol(agri_surface)))
head(agri_surface)

# %%
# Load anno2009_Decessi per comune RESIDENZA sesso e causa.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_anno2009_decessi_per_comune_residenza_sesso_e_causa`"
anno2009_decessi_per_comune_residenza_sesso_e_causa <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("anno2009_decessi_per_comune_residenza_sesso_e_causa: %d rows, %d columns\n", nrow(anno2009_decessi_per_comune_residenza_sesso_e_causa), ncol(anno2009_decessi_per_comune_residenza_sesso_e_causa)))
head(anno2009_decessi_per_comune_residenza_sesso_e_causa)

# %%
# Load anno2010_Decessi per comune RESIDENZA sesso e causa.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_anno2010_decessi_per_comune_residenza_sesso_e_causa`"
anno2010_decessi_per_comune_residenza_sesso_e_causa <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("anno2010_decessi_per_comune_residenza_sesso_e_causa: %d rows, %d columns\n", nrow(anno2010_decessi_per_comune_residenza_sesso_e_causa), ncol(anno2010_decessi_per_comune_residenza_sesso_e_causa)))
head(anno2010_decessi_per_comune_residenza_sesso_e_causa)

# %%
# Load anno2011_Decessi per comune RESIDENZA sesso e causa.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_anno2011_decessi_per_comune_residenza_sesso_e_causa`"
anno2011_decessi_per_comune_residenza_sesso_e_causa <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("anno2011_decessi_per_comune_residenza_sesso_e_causa: %d rows, %d columns\n", nrow(anno2011_decessi_per_comune_residenza_sesso_e_causa), ncol(anno2011_decessi_per_comune_residenza_sesso_e_causa)))
head(anno2011_decessi_per_comune_residenza_sesso_e_causa)

# %%
# Load anno2012_Decessi per comune RESIDENZA sesso e causa.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_anno2012_decessi_per_comune_residenza_sesso_e_causa`"
anno2012_decessi_per_comune_residenza_sesso_e_causa <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("anno2012_decessi_per_comune_residenza_sesso_e_causa: %d rows, %d columns\n", nrow(anno2012_decessi_per_comune_residenza_sesso_e_causa), ncol(anno2012_decessi_per_comune_residenza_sesso_e_causa)))
head(anno2012_decessi_per_comune_residenza_sesso_e_causa)

# %%
# Load anno2013_Decessi per comune RESIDENZA sesso e causa.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_anno2013_decessi_per_comune_residenza_sesso_e_causa`"
anno2013_decessi_per_comune_residenza_sesso_e_causa <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("anno2013_decessi_per_comune_residenza_sesso_e_causa: %d rows, %d columns\n", nrow(anno2013_decessi_per_comune_residenza_sesso_e_causa), ncol(anno2013_decessi_per_comune_residenza_sesso_e_causa)))
head(anno2013_decessi_per_comune_residenza_sesso_e_causa)

# %%
# Load anno2014_Decessi per comune RESIDENZA sesso e causa.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_anno2014_decessi_per_comune_residenza_sesso_e_causa`"
anno2014_decessi_per_comune_residenza_sesso_e_causa <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("anno2014_decessi_per_comune_residenza_sesso_e_causa: %d rows, %d columns\n", nrow(anno2014_decessi_per_comune_residenza_sesso_e_causa), ncol(anno2014_decessi_per_comune_residenza_sesso_e_causa)))
head(anno2014_decessi_per_comune_residenza_sesso_e_causa)

# %%
# Load anno2015_Decessi per comune RESIDENZA sesso e causa.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_anno2015_decessi_per_comune_residenza_sesso_e_causa`"
anno2015_decessi_per_comune_residenza_sesso_e_causa <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("anno2015_decessi_per_comune_residenza_sesso_e_causa: %d rows, %d columns\n", nrow(anno2015_decessi_per_comune_residenza_sesso_e_causa), ncol(anno2015_decessi_per_comune_residenza_sesso_e_causa)))
head(anno2015_decessi_per_comune_residenza_sesso_e_causa)

# %%
# Load anno2016_Decessi per comune RESIDENZA sesso e causa.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_anno2016_decessi_per_comune_residenza_sesso_e_causa`"
anno2016_decessi_per_comune_residenza_sesso_e_causa <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("anno2016_decessi_per_comune_residenza_sesso_e_causa: %d rows, %d columns\n", nrow(anno2016_decessi_per_comune_residenza_sesso_e_causa), ncol(anno2016_decessi_per_comune_residenza_sesso_e_causa)))
head(anno2016_decessi_per_comune_residenza_sesso_e_causa)

# %%
# Load anno2017_Decessi per comune RESIDENZA sesso e causa.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_anno2017_decessi_per_comune_residenza_sesso_e_causa`"
anno2017_decessi_per_comune_residenza_sesso_e_causa <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("anno2017_decessi_per_comune_residenza_sesso_e_causa: %d rows, %d columns\n", nrow(anno2017_decessi_per_comune_residenza_sesso_e_causa), ncol(anno2017_decessi_per_comune_residenza_sesso_e_causa)))
head(anno2017_decessi_per_comune_residenza_sesso_e_causa)

# %%
# Load anno2018_Decessi per comune RESIDENZA sesso e causa.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_anno2018_decessi_per_comune_residenza_sesso_e_causa`"
anno2018_decessi_per_comune_residenza_sesso_e_causa <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("anno2018_decessi_per_comune_residenza_sesso_e_causa: %d rows, %d columns\n", nrow(anno2018_decessi_per_comune_residenza_sesso_e_causa), ncol(anno2018_decessi_per_comune_residenza_sesso_e_causa)))
head(anno2018_decessi_per_comune_residenza_sesso_e_causa)

# %%
# Load anno2019_Decessi per comune RESIDENZA sesso e causa.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_anno2019_decessi_per_comune_residenza_sesso_e_causa`"
anno2019_decessi_per_comune_residenza_sesso_e_causa <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("anno2019_decessi_per_comune_residenza_sesso_e_causa: %d rows, %d columns\n", nrow(anno2019_decessi_per_comune_residenza_sesso_e_causa), ncol(anno2019_decessi_per_comune_residenza_sesso_e_causa)))
head(anno2019_decessi_per_comune_residenza_sesso_e_causa)

# %%
# Load covariates_census.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_covariates_census`"
covariates_census <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("covariates_census: %d rows, %d columns\n", nrow(covariates_census), ncol(covariates_census)))
head(covariates_census)

# %%
# Load demographics_istat.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_demographics_istat`"
demographics_istat <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("demographics_istat: %d rows, %d columns\n", nrow(demographics_istat), ncol(demographics_istat)))
head(demographics_istat)

# %%
# Load electoral_data.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_electoral_data`"
electoral_data <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("electoral_data: %d rows, %d columns\n", nrow(electoral_data), ncol(electoral_data)))
head(electoral_data)

# %%
# Load income_istat.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_income_istat`"
income_istat <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("income_istat: %d rows, %d columns\n", nrow(income_istat), ncol(income_istat)))
head(income_istat)

# %%
# Load intermunicipal_distances.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_intermunicipal_distances`"
intermunicipal_distances <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("intermunicipal_distances: %d rows, %d columns\n", nrow(intermunicipal_distances), ncol(intermunicipal_distances)))
head(intermunicipal_distances)

# %%
# Load muni_code_names_13.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_muni_code_names_13`"
muni_code_names_13 <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("muni_code_names_13: %d rows, %d columns\n", nrow(muni_code_names_13), ncol(muni_code_names_13)))
head(muni_code_names_13)

# %%
# Load municipal_crosswalk.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_municipal_crosswalk`"
municipal_crosswalk <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("municipal_crosswalk: %d rows, %d columns\n", nrow(municipal_crosswalk), ncol(municipal_crosswalk)))
head(municipal_crosswalk)

# %%
# Load partyfam_crosswalk.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_partyfam_crosswalk`"
partyfam_crosswalk <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("partyfam_crosswalk: %d rows, %d columns\n", nrow(partyfam_crosswalk), ncol(partyfam_crosswalk)))
head(partyfam_crosswalk)

# %%
# Load ps_hubs.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_ps_hubs`"
ps_hubs <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("ps_hubs: %d rows, %d columns\n", nrow(ps_hubs), ncol(ps_hubs)))
head(ps_hubs)

# %%
# Load puglia_regional_elections_2020.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_puglia_regional_elections_2020`"
puglia_regional_elections_2020 <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("puglia_regional_elections_2020: %d rows, %d columns\n", nrow(puglia_regional_elections_2020), ncol(puglia_regional_elections_2020)))
head(puglia_regional_elections_2020)

# %%
# Load referendum1946.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_referendum1946`"
referendum1946 <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("referendum1946: %d rows, %d columns\n", nrow(referendum1946), ncol(referendum1946)))
head(referendum1946)

# %%
# Load referendum1974.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_referendum1974`"
referendum1974 <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("referendum1974: %d rows, %d columns\n", nrow(referendum1974), ncol(referendum1974)))
head(referendum1974)

# %%
# Load referendum1981.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_referendum1981`"
referendum1981 <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("referendum1981: %d rows, %d columns\n", nrow(referendum1981), ncol(referendum1981)))
head(referendum1981)

# %%
# Load services_mef.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_services_mef`"
services_mef <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("services_mef: %d rows, %d columns\n", nrow(services_mef), ncol(services_mef)))
head(services_mef)

# %%
# Load xylella_areas.csv
sql <- "SELECT * FROM `polirep-app.paper_data.without_roots_xylella_xylella_areas`"
xylella_areas <- bq_project_query(project_id, sql) |> bq_table_download()
cat(sprintf("xylella_areas: %d rows, %d columns\n", nrow(xylella_areas), ncol(xylella_areas)))
head(xylella_areas)

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Load National Elections Data
#
# Load electoral data with party family aggregation and treatment variables.
# Merges electoral_data.tab with party family crosswalk, municipal crosswalk,
# and Xylella infection timing data.

# %%
source("r_clean/scripts/00_setup.R")
source("r_clean/scripts/01_data.R")
cat("Dimensions:", dim(national_elections), "\n")
cat("Municipalities:", length(unique(national_elections$com_id)), "\n")
cat("Elections:", length(unique(national_elections$election_year)), "\n")
cat("Mean farright_p:", mean(national_elections$farright_p, na.rm=TRUE), "\n")
head(national_elections[, c("com_id", "election_year", "farright_p", "treated", "xylella_group")], 10)

# %% [markdown]
# ### Create Treatment Variables
#
# Create treatment indicators: treated (ever infected), infected_dummy
# (infected by election date), and intensity (months since infection).
# Add election months and calculate time-to-treatment for event studies.

# %%
source("r_clean/scripts/00_setup.R")
source("r_clean/scripts/01_data.R")
cat("Treated municipalities:", sum(unique(national_elections$com_id) %in% national_elections$com_id[national_elections$treated==1]), "\n")
cat("Infected municipality-elections:", sum(national_elections$infected_dummy), "\n")
cat("Xylella groups:", sort(unique(national_elections$xylella_group)), "\n")

# %% [markdown]
# ### Calculate Vote Shares
#
# Aggregate votes by party family (farright, right, left, farleft, m5s)
# and calculate vote shares as % of total eligible voters. Also compute
# turnout as % of eligible voters.

# %%
source("r_clean/scripts/00_setup.R")
source("r_clean/scripts/01_data.R")
cat("Vote share means (%):\n")
for (var in c("farright_p", "right_p", "left_p", "farleft_p", "m5s_p", "turnout_p")) {
  if (var %in% names(national_elections)) {
    cat(sprintf("  %s: %.2f\n", var, mean(national_elections[[var]], na.rm=TRUE)))
  }
}

# %% [markdown]
# ### Load Demographics and Suicide Data
#
# Load demographics panel with suicide counts aggregated from death records
# (ICD-10 codes X60-X84 for intentional self-harm). Merge with Xylella
# infection timing.

# %%
source("r_clean/scripts/00_setup.R")
source("r_clean/scripts/01_data.R")
cat("Dimensions:", dim(demographics), "\n")
cat("Year range:", range(demographics$wave), "\n")
head(demographics[, c("com_id", "wave", "agegroup_20_35_ita")], 10)

# %% [markdown]
# ### Load Income Data
#
# Load income panel with pre-tax income per capita from MEF tax records.
# Calculate arcsinh transformation for robust analysis.

# %%
source("r_clean/scripts/00_setup.R")
source("r_clean/scripts/01_data.R")
cat("Dimensions:", dim(income), "\n")
cat("Year range:", range(income$year), "\n")
cat("Mean pretax_inc_pc:", mean(income$pretax_inc_pc, na.rm=TRUE), "\n")
head(income[, c("com_id", "year", "pretax_inc_pc", "arcsinh_pretax_pc")], 10)

# %% [markdown]
# ### Load Time-Invariant Covariates
#
# Load covariates from 2001/2011 censuses: demographics, economic structure,
# agricultural land use, distance to public service hubs, and social capital
# indicators. Calculate derived variables (shares, densities).

# %%
source("r_clean/scripts/00_setup.R")
source("r_clean/scripts/01_data.R")
cat("Dimensions:", dim(covariates), "\n")
cat("Mean dist_polo_2011:", mean(covariates$dist_polo_2011, na.rm=TRUE), "\n")
cat("Mean pop_11:", mean(covariates$pop_11, na.rm=TRUE), "\n")
head(covariates[, c("com_id", "pop_11", "dist_polo_2011")], 10)

# %% [markdown]
# ### Apply Sample Restrictions
#
# Filter main analysis sample: exclude xylella_group 7 (May 2019 infection,
# after 2018 election), restrict to Puglia, and exclude municipalities with
# corrupted voter data. Create time-to-treatment variable for event studies.

# %%
source("r_clean/scripts/00_setup.R")
source("r_clean/scripts/01_data.R")
cat("Main analysis sample:", nrow(df_main), "obs,", length(unique(df_main$com_id)), "municipalities\n")
cat("Treated municipalities:", sum(df_main$treated[!duplicated(df_main$com_id)]), "\n")
cat("Elections:", length(unique(df_main$election_year)), "\n")

# %% [markdown]
# ## Main DiD Analysis

# %% [markdown]
# ### Main DiD Analysis
#
# Two-way fixed effects DiD on five political outcomes (Table 1)

# %% [markdown]
# ## Event Study - Far-Right

# %% [markdown]
# ### Event Study - Far-Right
#
# Event study for far-right vote share showing parallel pre-trends (Figures 2a-2b)

# %% [markdown]
# ## Mechanism Tests

# %% [markdown]
# ### Mechanism Tests
#
# Testing economic mechanism: income and young residents (Figures 3a-3b)

# %% [markdown]
# ## Heterogeneous Effects by Public Services

# %% [markdown]
# ### Heterogeneous Effects by Public Services
#
# Treatment effect moderation by distance to public service hubs (Figure 4)

# %% [markdown]
# ## Case Illustrations

# %% [markdown]
# ### Case Illustrations
#
# Municipality-level trajectories of far-right voting over time (Figure 5)

# %% [markdown]
# ## Balance Table

# %% [markdown]
# ### Balance Table
#
# Pre-treatment balance test comparing treated vs control municipalities (Table B.19.1)

# %% [markdown]
# ## Suicide Event Study

# %% [markdown]
# ### Suicide Event Study
#
# Effect of epidemic on suicide rates, testing mental health mechanism (Figure B.7.1)

# %% [markdown]
# ## Dose-Response Analysis

# %% [markdown]
# ### Dose-Response Analysis
#
# Continuous treatment intensity (months since infection) instead of binary (Table B.4.1)
